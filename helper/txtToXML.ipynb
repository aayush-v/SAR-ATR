# %%
#This file is used to covnet annotations from .txt file to .xml fomate
from xml.dom.minidom import Document
import os
import os.path
from PIL import Image

# %%
ann_path = '/Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test'      
img_path = '/Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test'   
xml_path = '/Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test_xml/'

# %%
def writeXml(tmp, imgname, w, h, objbud, wxml):
    doc = Document()
    #Define class number according to the  classes in the .txt file
#     dict = {'0': "T72",
#             '1': "BTR60",
#             '2': "D7",
#             '3': "2S1",
#             '4': "BRDM_2",
#             '5': "T62",
#             '6': "ZIL131",
#             '7': "BMP2",
#             '8': "ZSU_23_4",
# 	    '9': "BTR70"}
    dict = {'0': "2S1",
            '1': "BRDM_2",
            '2': "BTR_60",
            '3': "D7",
            '4': "SLICY",
            '5': "T62",
            '6': "ZIL131",
            '7': "ZSU_23_4"}


    annotation = doc.createElement('annotation')
    doc.appendChild(annotation)
    # owner
    folder = doc.createElement('folder')
    annotation.appendChild(folder)
    folder_txt = doc.createTextNode("VOC2005")
    folder.appendChild(folder_txt)

    filename = doc.createElement('filename')
    annotation.appendChild(filename)
    filename_txt = doc.createTextNode(imgname)
    filename.appendChild(filename_txt)
    # ones#
    source = doc.createElement('source')
    annotation.appendChild(source)

    database = doc.createElement('database')
    source.appendChild(database)
    database_txt = doc.createTextNode("The VOC2005 Database")
    database.appendChild(database_txt)

    annotation_new = doc.createElement('annotation')
    source.appendChild(annotation_new)
    annotation_new_txt = doc.createTextNode("PASCAL VOC2005")
    annotation_new.appendChild(annotation_new_txt)

    image = doc.createElement('image')
    source.appendChild(image)
    image_txt = doc.createTextNode("flickr")
    image.appendChild(image_txt)
    # onee#
    # twos#
    size = doc.createElement('size')
    annotation.appendChild(size)

    width = doc.createElement('width')
    size.appendChild(width)
    width_txt = doc.createTextNode(str(w))
    width.appendChild(width_txt)

    height = doc.createElement('height')
    size.appendChild(height)
    height_txt = doc.createTextNode(str(h))
    height.appendChild(height_txt)

    depth = doc.createElement('depth')
    size.appendChild(depth)
    depth_txt = doc.createTextNode("3")
    depth.appendChild(depth_txt)
    # twoe#
    segmented = doc.createElement('segmented')
    annotation.appendChild(segmented)
    segmented_txt = doc.createTextNode("0")
    segmented.appendChild(segmented_txt)

    for i in range(0, int(len(objbud))):
        objbuds=objbud[i].split(' ')
        #print(objbuds)
        # threes#
        object_new = doc.createElement("object")
        annotation.appendChild(object_new)

        name = doc.createElement('name')
        object_new.appendChild(name)
        name_txt = doc.createTextNode(dict[objbuds[0]])
        name.appendChild(name_txt)

        pose = doc.createElement('pose')
        object_new.appendChild(pose)
        pose_txt = doc.createTextNode("Unspecified")
        pose.appendChild(pose_txt)

        truncated = doc.createElement('truncated')
        object_new.appendChild(truncated)
        truncated_txt = doc.createTextNode("0")
        truncated.appendChild(truncated_txt)

        difficult = doc.createElement('difficult')
        object_new.appendChild(difficult)
        difficult_txt = doc.createTextNode("0")
        difficult.appendChild(difficult_txt)
        # threes-1#
        bndbox = doc.createElement('bndbox')
        object_new.appendChild(bndbox)
        
        x1 = float(objbuds[1])
        y1 = float(objbuds[2])
        w1 = float(objbuds[3])
        h1 = float(objbuds[4])
        
        #xmin_txt1 = float(objbuds[1])  #0.674883
        #ymin_txt1 = float(objbuds[3])  #0.647917
        #xmax_txt1 = float(objbuds[2])  #0.143192
        #ymax_txt1 = float(objbuds[4])  #0.700000

        # w = 852
        # h =480

        
        xmin = doc.createElement('xmin')
        bndbox.appendChild(xmin)
                
     
        xmin_txt2 = int((x1*w) - (w1*w)/2.0)
        #print(xmin_txt2)
        xmin_txt = doc.createTextNode(str(xmin_txt2))
        xmin.appendChild(xmin_txt)

        ymin = doc.createElement('ymin')
        bndbox.appendChild(ymin)
        ymin_txt2 = int((y1*h)-(h1*h)/2.0)
        #print(ymin_txt2)
        ymin_txt = doc.createTextNode(str(ymin_txt2))
        ymin.appendChild(ymin_txt)

        xmax = doc.createElement('xmax')
        bndbox.appendChild(xmax) 
        xmax_txt2 = int((x1*w)+(w1*w)/2.0)
        #print(xmax_txt2)
        xmax_txt = doc.createTextNode(str(xmax_txt2))
        xmax.appendChild(xmax_txt)


        ymax = doc.createElement('ymax')
        bndbox.appendChild(ymax)
        ymax_txt2 = int((y1*h)+(h1*h)/2.0)
        #print(ymax_txt2)
        ymax_txt = doc.createTextNode(str(ymax_txt2))
        ymax.appendChild(ymax_txt)

        
        # threee-1#
        # threee#
        #xmin_txts = str(int((xmin_txt*w) + (xmax_txt*w)/2.0))
        #ymax_txts = str(int((ymin_txt*h)+(ymax_txt*h)/2.0))
        #ymin_txts = str(int((ymin_txt*h)+(ymax_txt*h)/2.0))
        
        #xmin.appendChild(xmin_txts)
        #ymin.appendChild(ymin_txts)
        #xmax.appendChild(xmax_txts)
        #ymax.appendChild(ymax_txts)

                
    tempfile = tmp + "test.xml"
    with open(tempfile, "w") as f:
        f.write(doc.toprettyxml(indent='\t'))

    rewrite = open(tempfile, "r")
    lines = rewrite.read().split('\n')
    newlines = lines[1:len(lines) - 1]

    fw = open(wxml, "w")
    for i in range(0, len(newlines)):
        fw.write(newlines[i] + '\n')

    fw.close()
    rewrite.close()
    os.remove(tempfile)
    return

# %%
for files in os.walk(ann_path):
    temp = './temp/'
    if not os.path.exists(temp):
        os.mkdir(temp)
#     print(files)
    for file in files[2]:
        if not file.endswith('txt'):
            continue
        print (file + "-->start!")
#         print(os.path.splitext(file)[0])
        img_name = os.path.splitext(file)[0] + '.JPG'
#         print(img_name)
        fileimgpath = img_path + '/' + img_name
        print(fileimgpath)
        im = Image.open(fileimgpath)
        width = int(im.size[0])
        height = int(im.size[1])

        filelabel = open(ann_path + '/' + file, "r")
        lines = filelabel.read().split('\n')
        print(lines)
    
        obj = lines[:len(lines)]
        print(obj)
#         print(obj[1])

        filename = xml_path + '/' + os.path.splitext(file)[0] + '.xml'
        writeXml(temp, img_name, width, height, obj, filename)
    os.rmdir(temp)
# Out:
# 002445.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/002445.JPG
# ['0 0.5 0.5 0.7 0.7']
# ['0 0.5 0.5 0.7 0.7']
# 003983.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/003983.JPG
# ['6 0.5 0.5 0.7 0.7']
# ['6 0.5 0.5 0.7 0.7']
# 004034.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/004034.JPG
# ['6 0.5 0.5 0.7 0.7']
# ['6 0.5 0.5 0.7 0.7']
# 002451.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/002451.JPG
# ['0 0.5 0.5 0.7 0.7']
# ['0 0.5 0.5 0.7 0.7']
# 003997.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/003997.JPG
# ['6 0.5 0.5 0.7 0.7']
# ['6 0.5 0.5 0.7 0.7']
# 004020.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/004020.JPG
# ['6 0.5 0.5 0.7 0.7']
# ['6 0.5 0.5 0.7 0.7']
# 003029.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/003029.JPG
# ['2 0.5 0.5 0.7 0.7']
# ['2 0.5 0.5 0.7 0.7']
# 003001.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/003001.JPG
# ['2 0.5 0.5 0.7 0.7']
# ['2 0.5 0.5 0.7 0.7']
# 002479.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/002479.JPG
# ['0 0.5 0.5 0.7 0.7']
# ['0 0.5 0.5 0.7 0.7']
# 004008.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/004008.JPG
# ['6 0.5 0.5 0.7 0.7']
# ['6 0.5 0.5 0.7 0.7']
# 003767.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/003767.JPG
# ['5 0.5 0.5 0.7 0.7']
# ['5 0.5 0.5 0.7 0.7']
# 003773.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/003773.JPG
# ['5 0.5 0.5 0.7 0.7']
# ['5 0.5 0.5 0.7 0.7']
# 003015.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/003015.JPG
# ['2 0.5 0.5 0.7 0.7']
# ['2 0.5 0.5 0.7 0.7']
# 003798.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/003798.JPG
# ['5 0.5 0.5 0.7 0.7']
# ['5 0.5 0.5 0.7 0.7']
# 002486.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/002486.JPG
# ['0 0.5 0.5 0.7 0.7']
# ['0 0.5 0.5 0.7 0.7']
# 003940.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/003940.JPG
# ['6 0.5 0.5 0.7 0.7']
# ['6 0.5 0.5 0.7 0.7']
# 002492.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/002492.JPG
# ['0 0.5 0.5 0.7 0.7']
# ['0 0.5 0.5 0.7 0.7']
# 003954.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/003954.JPG
# ['6 0.5 0.5 0.7 0.7']
# ['6 0.5 0.5 0.7 0.7']
# 003968.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/003968.JPG
# ['6 0.5 0.5 0.7 0.7']
# ['6 0.5 0.5 0.7 0.7']
# 003559.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/003559.JPG
# ['4 0.5 0.5 0.7 0.7']
# ['4 0.5 0.5 0.7 0.7']
# 004236.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/004236.JPG
# ['7 0.5 0.5 0.7 0.7']
# ['7 0.5 0.5 0.7 0.7']
# 002647.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/002647.JPG
# ['1 0.5 0.5 0.7 0.7']
# ['1 0.5 0.5 0.7 0.7']
# 004222.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/004222.JPG
# ['7 0.5 0.5 0.7 0.7']
# ['7 0.5 0.5 0.7 0.7']
# 002653.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/002653.JPG
# ['1 0.5 0.5 0.7 0.7']
# ['1 0.5 0.5 0.7 0.7']
# 003565.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/003565.JPG
# ['4 0.5 0.5 0.7 0.7']
# ['4 0.5 0.5 0.7 0.7']
# 003203.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/003203.JPG
# ['3 0.5 0.5 0.7 0.7']
# ['3 0.5 0.5 0.7 0.7']
# 003217.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/003217.JPG
# ['3 0.5 0.5 0.7 0.7']
# ['3 0.5 0.5 0.7 0.7']
# 003571.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/003571.JPG
# ['4 0.5 0.5 0.7 0.7']
# ['4 0.5 0.5 0.7 0.7']
# 002684.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/002684.JPG
# ['1 0.5 0.5 0.7 0.7']
# ['1 0.5 0.5 0.7 0.7']
# 002690.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/002690.JPG
# ['1 0.5 0.5 0.7 0.7']
# ['1 0.5 0.5 0.7 0.7']
# 002848.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/002848.JPG
# ['1 0.5 0.5 0.7 0.7']
# ['1 0.5 0.5 0.7 0.7']
# 002860.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/002860.JPG
# ['1 0.5 0.5 0.7 0.7']
# ['1 0.5 0.5 0.7 0.7']
# 002874.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/002874.JPG
# ['1 0.5 0.5 0.7 0.7']
# ['1 0.5 0.5 0.7 0.7']
# 002733.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/002733.JPG
# ['1 0.5 0.5 0.7 0.7']
# ['1 0.5 0.5 0.7 0.7']
# 004342.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/004342.JPG
# ['7 0.5 0.5 0.7 0.7']
# ['7 0.5 0.5 0.7 0.7']
# 004424.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/004424.JPG
# ['7 0.5 0.5 0.7 0.7']
# ['7 0.5 0.5 0.7 0.7']
# 004430.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/004430.JPG
# ['7 0.5 0.5 0.7 0.7']
# ['7 0.5 0.5 0.7 0.7']
# 002727.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/002727.JPG
# ['1 0.5 0.5 0.7 0.7']
# ['1 0.5 0.5 0.7 0.7']
# 004356.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/004356.JPG
# ['7 0.5 0.5 0.7 0.7']
# ['7 0.5 0.5 0.7 0.7']
# 003439.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/003439.JPG
# ['4 0.5 0.5 0.7 0.7']
# ['4 0.5 0.5 0.7 0.7']
# 003411.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/003411.JPG
# ['4 0.5 0.5 0.7 0.7']
# ['4 0.5 0.5 0.7 0.7']
# 003377.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/003377.JPG
# ['4 0.5 0.5 0.7 0.7']
# ['4 0.5 0.5 0.7 0.7']
# 004418.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/004418.JPG
# ['7 0.5 0.5 0.7 0.7']
# ['7 0.5 0.5 0.7 0.7']
# 003363.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/003363.JPG
# ['4 0.5 0.5 0.7 0.7']
# ['4 0.5 0.5 0.7 0.7']
# 003405.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/003405.JPG
# ['4 0.5 0.5 0.7 0.7']
# ['4 0.5 0.5 0.7 0.7']
# 002928.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/002928.JPG
# ['2 0.5 0.5 0.7 0.7']
# ['2 0.5 0.5 0.7 0.7']
# 004381.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/004381.JPG
# ['7 0.5 0.5 0.7 0.7']
# ['7 0.5 0.5 0.7 0.7']
# 003388.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/003388.JPG
# ['4 0.5 0.5 0.7 0.7']
# ['4 0.5 0.5 0.7 0.7']
# 004395.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/004395.JPG
# ['7 0.5 0.5 0.7 0.7']
# ['7 0.5 0.5 0.7 0.7']
# 002914.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/002914.JPG
# ['2 0.5 0.5 0.7 0.7']
# ['2 0.5 0.5 0.7 0.7']
# 002900.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/002900.JPG
# ['2 0.5 0.5 0.7 0.7']
# ['2 0.5 0.5 0.7 0.7']
# 003149.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/003149.JPG
# ['3 0.5 0.5 0.7 0.7']
# ['3 0.5 0.5 0.7 0.7']
# 004140.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/004140.JPG
# ['6 0.5 0.5 0.7 0.7']
# ['6 0.5 0.5 0.7 0.7']
# 002531.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/002531.JPG
# ['0 0.5 0.5 0.7 0.7']
# ['0 0.5 0.5 0.7 0.7']
# 004154.txt-->start!
# /Users/aayushverma/Desktop/4-2/SOP2/custom/DataOriginal/dataset_non_proc/test/004154.JPG
# ['6 0.5 0.5 0.7 0.7']
# ['6 0.5 0.5 0.7 0.7']
# 